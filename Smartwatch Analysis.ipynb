# %% [markdown]
# # **Introduction**
#
# **1. Purpose and Objectives :**
#              The purpose of this project is to analyze smartwatch data to understand user behavior and identify trends related to physical activity, heart rate, and overall fitness.
#
#  **2. Problem Statement :**
#               Understanding user fitness habits from smartwatch data is crucial for providing actionable insights to improve health and device utility
#
#  **3. Relevance :**
#  This project is relevant as it provides insights into the impact of wearable devices on fitness and user engagement.
#
# **4. High-Level Approach:** We used data cleaning, exploratory analysis, and visualizations to uncover trends in user activity and device usage.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('smartwatch.csv')

# %%
df.dtypes
# Out:
# Unnamed: 0                int64
# X1                        int64
# age                       int64
# gender                    int64
# height                  float64
# weight                  float64
# steps                   float64
# hear_rate               float64
# calories                float64
# distance                float64
# entropy_heart           float64
# entropy_setps           float64
# resting_heart           float64
# corr_heart_steps        float64
# norm_heart              float64
# intensity_karvonen      float64
# sd_norm_heart           float64
# steps_times_distance    float64
# device                   object
# activity                 object
# dtype: object

# %%
import pandas as pd
df = pd.read_csv('smartwatch.csv')
print(df.isnull().sum())
# Out:
# Column1                 0
# X1                      0
# age                     0
# gender                  0
# height                  0
# weight                  0
# steps                   0
# hear_rate               0
# calories                0
# distance                0
# entropy_heart           0
# entropy_setps           0
# resting_heart           0
# corr_heart_steps        0
# norm_heart              0
# intensity_karvonen      0
# sd_norm_heart           0
# steps_times_distance    0
# device                  0
# activity                0
# dtype: int64

# %% [markdown]
# # **Data Cleaning and Preprocessing**
#
# We removed columns (**X** and **Y**) as they contained irrelevant data, and renamed column Z for clarity and also rename the incorrectly labeled column **hear_rate** to **Heart_rate** for clarity and consistency.

# %%
import pandas as pd
df = pd.read_csv('smartwatch.csv', usecols=lambda column: column not in ['Column 1', 'X1'])
df = df.rename(columns={'hear_rate':'Heart_rate'})

print(df.head())
# Out:
#    Column1  age  gender  height  weight      steps  Heart_rate   calories  \
# 0        1   20       1   168.0    65.4  10.771429   78.531302   0.344533
# 1        2   20       1   168.0    65.4  11.475325   78.453390   3.287625
# 2        3   20       1   168.0    65.4  12.179221   78.540825   9.484000
# 3        4   20       1   168.0    65.4  12.883117   78.628260  10.154556
# 4        5   20       1   168.0    65.4  13.587013   78.715695  10.825111
#
#    distance  entropy_heart  entropy_setps  resting_heart  corr_heart_steps  \
# 0  0.008327       6.221612       6.116349           59.0          1.000000
# 1  0.008896       6.221612       6.116349           59.0          1.000000
# 2  0.009466       6.221612       6.116349           59.0          1.000000
# 3  0.010035       6.221612       6.116349           59.0          1.000000
# 4  0.010605       6.221612       6.116349           59.0          0.982816
#
# ...

# %% [markdown]
# # **Key Insights:**
#
#
#
# **1. Demographics :**
#
#
# *  Most users are aged 20–30, with a balanced gender split.
#
#
# **2. List item :**
#
#
# *  Daily steps and distance vary widely; some users are highly active, while others are sedentary.
# *  Average calories burned is ~19, with a few users burning significantly more, likely due to intense activities
#
#
#
# **3. Heart Rate: :**
#
#
# *   List itemAverage heart rate is ~86 bpm, and resting heart rate is ~65 bpm.
# *  Some extreme values indicate possible data errors or specific health conditions.
#
# **4. Device & Activity:**
#
# * A mix of activities like "Walking," "Running," and "Lying" shows diverse usage patterns.
# * Different devices are used, with trends likely linked to user preferences.
#
# **5. Intensity & Trends:**
#
# * Activity intensity is generally low, but a few users engage in high-intensity workouts.
# * Some extreme values (e.g., high steps or distance) could be from athletes or unique events.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('smartwatch.csv')
average_steps = df['steps'].mean()
print(f"The average value of steps is: {average_steps:.2f}")
# Out:
# The average value of steps is: 109.56

# %% [markdown]
# # Steps range from 1 to 1,714, with an average of 109.56.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataframe and rename the column 'hear_rate' to 'Heart_rate'
df = pd.read_csv('smartwatch.csv')
df = df.rename(columns={'hear_rate': 'Heart_rate'}) #Rename the column here

average_heart_rate = df['Heart_rate'].mean()
print(f"The average heart rate is: {average_heart_rate:.2f}")
# Out:
# The average heart rate is: 86.14

# %% [markdown]
# Heart rate values average at 86.14 BPM but can go as low as 2.22 and as high as 194.33 BPM

# %% [markdown]
# # **Exploratory Data Analysis (EDA)**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 8))
colors = ['lightcoral', 'skyblue']
plt.pie(gender_counts, labels=labels, autopct='%1.1f%%', colors=colors, startangle=140)
plt.title("Gender Ratio in Dataset", fontsize=16)

# Add legend
plt.legend(labels, title="Gender")

plt.show()

# %% [markdown]
# # **Gender Ratio in Dataset:**
# The pie chart represents the gender distribution in the dataset, showing the proportion of males and females.
#
# **1. Color Coding:**
#
# * Females are represented by light coral.
# * Males are represented by sky blue.
#
# **2. Observations:**
#
# **Female Percentage:**
# * The percentage of females in the dataset is shown as 52.3%.
#
# **Male Percentage:**
# * The percentage of males is 47.7%.
#
# The chart provides a clear visual representation of the gender distribution, with females slightly outnumbering males in the dataset.
# Legend:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your data is loaded into 'df' and gender is represented as 0 and 1

# ... (previous code to create male_df and female_df) ...

# Combined area graph for males and females
plt.figure(figsize=(10, 6))

male_age_counts = male_df['age'].value_counts().sort_index()
plt.fill_between(male_age_counts.index, male_age_counts.values, color='skyblue', alpha=0.7, label='Male')

female_age_counts = female_df['age'].value_counts().sort_index()
plt.fill_between(female_age_counts.index, female_age_counts.values, color='lightcoral', alpha=0.7, label='Female')

plt.title('Age Distribution for Males and Females')
plt.xlabel('Age')
plt.ylabel('Count')
plt.legend() # Add legend to distinguish male and female areas
plt.show()

# %% [markdown]
# # **Age Distribution for Males and Females:**
# The area graph illustrates the distribution of ages for males and females in the dataset:
#
# **1. Color Coding:**
#
# * Males are represented by sky blue, and females by light coral.
#
# **2. Observations:**
#
# **Male Age Distribution:**
# * The age distribution for males shows several peaks, with a higher concentration of males in younger age groups. The graph indicates that a significant number of males fall within the mid-20s to early 30s age range.
#
# **Female Age Distribution:**
# * The age distribution for females is also concentrated in younger age groups, with a notable peak in the late 20s to early 30s, similar to males. However, the distribution is slightly broader for females, indicating more variation in age compared to males.
#
# **Comparison:**
# * Both males and females show a significant number of participants in their respective younger age groups, but the female distribution has a more even spread across ages.
# * The male distribution appears to have a more centralized peak in the younger adult range, indicating fewer older participants.
#
# This area graph highlights the age range of participants across genders and visually represents how age distribution varies between males and females in the dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches

# Assuming your data is loaded into 'df' and has columns 'activity' and 'gender'
df = pd.read_csv('smartwatch.csv')  # Replace 'your_data.csv' with your actual file name

# Group data by activity and gender, then count occurrences
activity_gender_counts = df.groupby(['activity', 'gender'])['gender'].count().reset_index(name='count')

# Create a bar plot with color-coded gender
plt.figure(figsize=(12, 6))
sns.barplot(x='activity', y='count', hue='gender', data=activity_gender_counts,
            palette={0: 'lightcoral', 1: 'skyblue'})

plt.title('Activity Distribution by Gender')
plt.xlabel('Activity')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent labels from overlapping

# Manually create legend with colored patches
female_patch = mpatches.Patch(color='lightcoral', label='Female')
male_patch = mpatches.Patch(color='skyblue', label='Male')
plt.legend(handles=[female_patch, male_patch], title='Gender')

plt.show()

# %% [markdown]
# # **Activity Distribution by Gender:**
# The bar graph highlights the distribution of activities performed by males and females:
#
# 1. **Color Coding:**
# * Females are represented in light coral, and males in sky blue.
# 2. **Observations:**
# * Some activities, like "Walking" and "Running," are equally distributed across genders, suggesting similar engagement levels.
# * Others, like "Lying" or low-intensity activities, show slight differences, with one gender being more prominent.
# * Activities with fewer counts may represent niche or specialized tasks performed more by one gender.
#
# This visualization effectively demonstrates the diversity in activity preferences and participation between genders.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('smartwatch.csv')
activity_gender_calories = df.groupby(['activity', 'gender'])['calories'].sum().reset_index()

# Pivot the data to create a suitable format for stacked bar chart
pivoted_data = activity_gender_calories.pivot(index='activity', columns='gender', values='calories')

# Create the stacked bar chart
pivoted_data.plot(kind='bar', stacked=True, figsize=(12, 6), color=['lightcoral', 'skyblue'])

plt.title('Calories Burned by Activity Type and Gender')
plt.xlabel('Activity')
plt.ylabel('Total Calories Burned')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Manually create legend with colored patches (since stacked bar chart doesn't have hue)
import matplotlib.patches as mpatches  # Importing here for clarity
female_patch = mpatches.Patch(color='lightcoral', label='Female')
male_patch = mpatches.Patch(color='skyblue', label='Male')
plt.legend(handles=[female_patch, male_patch], title='Gender')

plt.show()

# %% [markdown]
# # **Calories Burned by Activity Type and Gender:**
# The stacked bar chart illustrates the total calories burned for each activity type, segmented by gender:
#
# 1. **Color Coding:**
# * Females are represented in light coral, and males in sky blue.
# 2. **Observations:**
# * Certain activities, such as "Running" and "Cycling," account for the highest calorie expenditure across both genders, reflecting their intensity.
# * Activities like "Lying" or "Sitting" show significantly lower calorie burns, with minor variations between genders.
# * The distribution highlights that males tend to burn more calories in high-intensity activities, while females dominate calorie expenditure in some moderate activities.
#
# This visualization provides insights into gender differences in calorie burn across various physical activities, emphasizing activity-specific energy demands.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('smartwatch.csv')

# Create the violin plot
plt.figure(figsize=(8, 6))
# Changed the keys in the palette dictionary to strings '0' and '1'
sns.violinplot(x='gender', y='calories', data=df, palette={'0': 'lightcoral', '1': 'skyblue'})

plt.title('Calories Burned Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Calories Burned')
plt.xticks([0, 1], ['Female', 'Male'])  # Set custom x-axis labels

plt.show()
# Out:
# <ipython-input-7-5e7b0e0ec0d3>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='gender', y='calories', data=df, palette={'0': 'lightcoral', '1': 'skyblue'})

# %% [markdown]
# # **Calories Burned Distribution by Gender:**
# The violin plot provides an in-depth look at the distribution of calories burned across genders, allowing us to observe the spread, median, and density of the data:
#
# **1. Color Coding:**
#
# * Females are represented in light coral, and males in sky blue.
#
# **2. Observations:**
# * Both genders show similar distributions, with the calorie burn for both female and male participants being spread over a wide range.
# * The median line (center of the plot) for females appears slightly lower than for males, suggesting females tend to burn fewer calories on average.
# * The density curves show more variation for males, with some outliers at higher calorie burns.
# * There is a wider range of values for males compared to females, indicating that some male participants have significantly higher calorie burns.
# * Skewness is apparent in the distributions, with some participants burning extremely high calories in both genders.
#
# This plot is useful in understanding how calories burned differ between genders and how consistent or variable these values are across individuals.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the dataset
df = pd.read_csv('smartwatch.csv')

# Group data by gender and calculate the average for steps, calories, and distance
gender_stats = df.groupby('gender')[['steps', 'calories', 'distance']].mean().reset_index()

# Melt the DataFrame to create a suitable format for grouped bar chart
melted_data = pd.melt(gender_stats, id_vars=['gender'], value_vars=['steps', 'calories', 'distance'],
                      var_name='Metric', value_name='Average')

# Create the grouped bar chart
plt.figure(figsize=(10, 6))
# Changed the keys in the palette dictionary to integers 0 and 1
sns.barplot(x='Metric', y='Average', hue='gender', data=melted_data, palette={0: 'lightcoral', 1: 'skyblue'})
plt.title('Steps, Calories, and Distance by Gender')
plt.xlabel('Metric')
plt.ylabel('Average')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability

# Manually create legend with colored patches
import matplotlib.patches as mpatches  # Importing here for clarity
female_patch = mpatches.Patch(color='lightcoral', label='Female')
male_patch = mpatches.Patch(color='skyblue', label='Male')
plt.legend(handles=[female_patch, male_patch], title='Gender')

plt.tight_layout()  # Adjust layout to prevent labels from overlapping
plt.show()

# %% [markdown]
# # **Steps, Calories, and Distance by Gender:**
# This grouped bar chart compares the average steps, calories burned, and distance traveled by gender:
#
# **1. Color Coding:**
#
# Females are represented in light coral, and males in sky blue.
#
# **2. Observations:**
#
# **Steps:**
# * Males have a higher average number of steps than females, indicating they tend to walk more or engage in physical activity more frequently.
#
# **Calories:**
# * Males burn more calories on average compared to females, possibly due to higher intensity activities or longer durations of physical activity.
#
# **Distance:**
# * Males also cover a greater average distance than females, reflecting the trend of higher physical activity levels in this gender group.
#
# This chart provides a clear comparison of physical activity metrics (steps, calories, and distance) between genders, highlighting significant differences in activity levels and calorie expenditure.

# %%
df = df.rename(columns={'hear_rate': 'Heart_rate'})

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
df = pd.read_csv('smartwatch.csv')

# Rename the column 'hear_rate' to 'Heart_rate'
if 'hear_rate' in df.columns:
    df = df.rename(columns={'hear_rate': 'Heart_rate'})

# Drop rows with missing Heart_rate values
df = df.dropna(subset=['Heart_rate'])

# Debug: Check unique values in the 'gender' column
print("Unique values in 'gender':", df['gender'].unique())

# Create the KDE plot
plt.figure(figsize=(10, 6))
sns.kdeplot(
    data=df,
    x='Heart_rate',
    hue='gender',
    fill=True,
    common_norm=False,
    palette={0: 'lightcoral', 1: 'skyblue'}  # Use integer keys
)

plt.title('Heart Rate Distribution by Gender')
plt.xlabel('Heart Rate (BPM)')
plt.ylabel('Density')

# Customize legend labels
plt.legend(title='Gender', labels=['Male', 'Female'])

plt.show()
# Out:
# Unique values in 'gender': [1 0]

# %% [markdown]
# # **Heart Rate Distribution by Gender:**
# The KDE (Kernel Density Estimate) plot illustrates the distribution of heart rates (in BPM) by gender:
#
# **1. Color Coding:**
#
# Females are represented in light coral, and males in sky blue.
#
# **2. Observations:**
#
# * The female heart rate distribution shows a peak at lower BPM values, indicating that females in the dataset tend to have a lower average heart rate.
# * The male heart rate distribution is more spread out and shifted towards higher BPM values, suggesting higher average heart rates or more variation in heart rate across the male participants.
# * The densities of heart rates are separated with males showing a broader distribution, while females concentrate more around a lower heart rate.
# * Both distributions have skewness, but the female distribution seems more compact compared to the male distribution.
#
# This plot provides insights into the differences in heart rate patterns between males and females, highlighting that gender may influence cardiovascular metrics.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
df = pd.read_csv('smartwatch.csv')

# Rename the column 'hear_rate' to 'Heart_rate' if it exists
if 'hear_rate' in df.columns:
    df = df.rename(columns={'hear_rate': 'Heart_rate'})
else:
    print("Column 'hear_rate' not found, assuming 'Heart_rate' already exists.")

# Select the columns for the pair plot
columns_for_pairplot = ['steps', 'distance', 'calories', 'Heart_rate']

# Ensure 'gender' column exists before creating the pair plot
if 'gender' not in df.columns:
    raise KeyError("The 'gender' column is not found in the DataFrame. Please check your data.")

# Create the pair plot
sns.pairplot(df[columns_for_pairplot + ['gender']], hue='gender', palette={0: 'lightcoral', 1: 'skyblue'})  # Include 'gender' in the data for hue
plt.suptitle('Pairwise Relationships between Steps, Distance, Calories, and Heart Rate', y=1.02)
plt.show()

# %% [markdown]
# # **Pairwise Relationships between Steps, Distance, Calories, and Heart Rate:**
# This pair plot visualizes the relationships between steps, distance, calories, and heart rate, with data separated by gender:
#
# **1. Color Coding:**
#
# Females are represented in light coral, and males in sky blue.
#
# **2. Observations:**
#
# **Steps and Distance:**
# * There is a noticeable positive correlation between steps and distance for both genders. As the number of steps increases, so does the distance covered.
#
# **Steps and Calories:**
# * Calories burned tends to increase with steps for both genders. However, the relationship appears stronger for males, indicating that males may burn more calories per step.
#
# **Distance and Calories:**
# * Similarly, there is a positive correlation between distance and calories. Participants who cover more distance tend to burn more calories, with this trend being more pronounced in males.
#
# **Heart Rate and Other Metrics:**
# * There is no clear, strong correlation between heart rate and other variables like steps, distance, or calories. Heart rate distribution shows more variation, indicating it may depend on individual fitness levels or other factors not captured in the dataset.
#
# **Gender Differences:**
# * Overall, males show higher values for steps, distance, calories burned, and heart rate compared to females, especially in the top-right of the scatter plots.
#
# **Scatter Plot Distribution:**
# * In most of the scatter plots, males tend to have more spread out values, while females show less variation but more concentration in lower ranges.
#
# This pair plot helps us understand how different physical activity metrics interact with each other, with gender differences clearly shown across the variables.

# %% [markdown]
# # **Conclusion**
#
# **1. Key Takeaways :** Most users are aged 20–30 and engage in moderate activity levels, with average heart rates of ~86 bpm.
#
# **2.Objective Achievement :** We identified patterns in user activity and heart rate trends, meeting the project's objectives.
#
# **3. Limitations :** Some extreme values might skew the results due to inaccurate device readings.
#
# **4. Future Work :** Further analysis could involve comparing trends across different time periods or integrating more demographic data.
